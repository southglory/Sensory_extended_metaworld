# %%
#@title All `dm_control` imports required for this tutorial

# The basic mujoco wrapper.
from dm_control import mujoco

# Access to enums and MuJoCo library functions.
from dm_control.mujoco.wrapper.mjbindings import enums
from dm_control.mujoco.wrapper.mjbindings import mjlib

# PyMJCF
from dm_control import mjcf

# Composer high level imports
from dm_control import composer
from dm_control.composer.observation import observable
from dm_control.composer import variation

# Imports for Composer tutorial example
from dm_control.composer.variation import distributions
from dm_control.composer.variation import noises
from dm_control.locomotion.arenas import floors

# Control Suite
from dm_control import suite

# Run through corridor example
from dm_control.locomotion.walkers import cmu_humanoid
from dm_control.locomotion.arenas import corridors as corridor_arenas
from dm_control.locomotion.tasks import corridors as corridor_tasks

# Soccer
from dm_control.locomotion import soccer

# Manipulation
from dm_control import manipulation

# %%
#@title Other imports and helper functions

# General
import copy
import os
from IPython.display import clear_output
import numpy as np

# Graphics-related
import matplotlib
import matplotlib.animation as animation
import matplotlib.pyplot as plt
from IPython.display import HTML
import PIL.Image

# Use svg backend for figure rendering
# %config InlineBackend.figure_format = 'svg'

# Font sizes
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# Inline video helper function
if os.environ.get('COLAB_NOTEBOOK_TEST', False):
  # We skip video generation during tests, as it is quite expensive.
  display_video = lambda *args, **kwargs: None
else:
  def display_video(frames, framerate=30):
    height, width, _ = frames[0].shape
    dpi = 70
    orig_backend = matplotlib.get_backend()
    matplotlib.use('Agg')  # Switch to headless 'Agg' to inhibit figure rendering.
    fig, ax = plt.subplots(1, 1, figsize=(width / dpi, height / dpi), dpi=dpi)
    matplotlib.use(orig_backend)  # Switch back to the original backend.
    ax.set_axis_off()
    ax.set_aspect('equal')
    ax.set_position([0, 0, 1, 1])
    im = ax.imshow(frames[0])
    def update(frame):
      im.set_data(frame)
      return [im]
    interval = 1000/framerate
    anim = animation.FuncAnimation(fig=fig, func=update, frames=frames,
                                   interval=interval, blit=True, repeat=False)
    return HTML(anim.to_html5_video())

# Seed numpy's global RNG so that cell outputs are deterministic. We also try to
# use RandomState instances that are local to a single cell wherever possible.
np.random.seed(42)

# %%
#@title A static model {vertical-output: true}

static_model = """
<mujoco>
  <worldbody>
    <light name="top" pos="0 0 1"/>
    <geom name="red_box" type="box" size=".2 .2 .2" rgba="1 0 0 1"/>
    <geom name="green_sphere" pos=".2 .2 .2" size=".1" rgba="0 1 0 1"/>
  </worldbody>
</mujoco>
"""
physics = mujoco.Physics.from_xml_string(static_model)
pixels = physics.render()
PIL.Image.fromarray(pixels)
# Out:
# <PIL.Image.Image image mode=RGB size=320x240 at 0x7FB503352AC0>

# %%
contents = open("../../mujoco/sawyer_xyz/v1/sawyer_pick_and_place.xml").read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 contents = open("sawyer_pick_and_place.xml").read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sawyer_pick_and_place.xml'

# %%
contents
# Out:
# '<?xml version="1.0" encoding="utf-8"?>\n<mujoco>\n    <include file="shared_config.xml"></include>\n    <worldbody>\n        <include file="sawyer_xyz_base.xml"></include>\n        <body name="obj" pos="0 0.6 0.02">\n            <joint name="objjoint" type="free" limited=\'false\' damping="0" armature="0" />\n            <inertial pos="0 0 0" mass="0.01" diaginertia="100000 100000 100000"/>\n            <geom name="objGeom" type="box" pos="0 0 0"\n                  size="0.02 0.02 0.02" rgba="0 0 1 1"\n                  contype="1" conaffinity="1" friction="1 0.1 0.002" condim="3" \n            />\n           <!--  <site name="obj" pos="0 0 0" size="0.01" /> -->\n        </body>\n\n\n        <!-- <site name="goal" pos="0.3 0.9 0.03" size="0.02" \n              rgba="1 0.5 0.5 0"/> -->\n        <site name="goal" pos="0.3 0.9 0.05" size="0.02" \n              rgba="0 0.8 0 1"/>\n\n        <!-- <site name="goalSpace" pos="0 0.75 0.02" size="0.02"\n              rgba="0 0.7 0 1" /> -->\n\n       <!--  <site name="goal_m1" pos="0.17 0.85 0.02" size="0.02"\n              rgba="1 0 0 1"/>\n\n        <site name="goal_m2" pos="-0.17 0.85 0.02" size="0.02"\n              rgba="1 0 0 1"/>\n\n        <site name="goal_m3" pos="0.17 0.45 0.02" size="0.02"\n              rgba="1 0 0 1"/>\n\n        <site name="goal_m4" pos="-0.17 0.45 0.02" size="0.02"\n              rgba="1 0 0 1"/>\n\n         <site name="goal_m5" pos="0.17 0.6 0.02" size="0.02"\n              rgba="1 0 0 1"/>\n\n        <site name="goal_m6" pos="-0.17 0.6 0.02" size="0.02"\n              rgba="1 0 0 1"/> -->\n\n       \n    </worldbody>\n    <!-- <sensor>\n        <touch name=\'rightclaw_sensor\' site=\'rightEndEffector\'/>\n        <touch name=\'leftclaw_sensor\' site=\'leftEndEffector\'/>\n    </sensor> -->\n    <actuator>\n        <position ctrllimited="true" ctrlrange="-1 1" joint="rc_close" kp="400"  user="1"/>\n        <position ctrllimited="true" ctrlrange="-1 1" joint="lc_close" kp="400"  user="1"/>\n       \n    </actuator>\n</mujoco>\n'

# %%
physics = mujoco.Physics.from_xml_string(contents)
pixels = physics.render()
PIL.Image.fromarray(pixels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 physics = mujoco.Physics.from_xml_string(contents)
#       2 pixels = physics.render()
#       3 PIL.Image.fromarray(pixels)
#
# File ~/anaconda3/envs/metaGarage/lib/python3.9/site-packages/dm_control/mujoco/engine.py:423, in Physics.from_xml_string(cls, xml_string, assets)
#     409 @classmethod
#     410 def from_xml_string(cls, xml_string, assets=None):
#     411   """A named constructor from a string containing an MJCF XML file.
#     412
#     413   Args:
#    (...)
#     421     A new `Physics` instance.
#     422   """
# --> 423   model = wrapper.MjModel.from_xml_string(xml_string, assets=assets)
#     424   return cls.from_model(model)
#
# File ~/anaconda3/envs/metaGarage/lib/python3.9/site-packages/dm_control/mujoco/wrapper/core.py:302, in MjModel.from_xml_string(cls, xml_string, assets)
#     288 @classmethod
#     289 def from_xml_string(cls, xml_string, assets=None):
#     290   """Creates an `MjModel` instance from a model description XML string.
#     291
#     292   Args:
#    (...)
#     300     An `MjModel` instance.
#     301   """
# --> 302   model_ptr = _get_model_ptr_from_xml(xml_string=xml_string, assets=assets)
#     303   return cls(model_ptr)
#
# File ~/anaconda3/envs/metaGarage/lib/python3.9/site-packages/dm_control/mujoco/wrapper/core.py:187, in _get_model_ptr_from_xml(xml_path, xml_string, assets)
#     183   raise TypeError(
#     184       "Only one of `xml_path` or `xml_string` may be specified.")
#     186 if xml_string is not None:
# --> 187   ptr = mujoco.MjModel.from_xml_string(xml_string, assets or {})
#     188 else:
#     189   ptr = mujoco.MjModel.from_xml_path(xml_path, assets or {})
#
# ValueError: XML Error: Include error: 'XML parse error 3:
# Error=XML_ERROR_FILE_NOT_FOUND ErrorID=3 (0x3) Line number=0: filename=shared_config.xml
# '
# Element 'include', line 3

# %%
physics = mujoco.Physics.from_xml_string(contents)
# Visualize the joint axis.
scene_option = mujoco.wrapper.core.MjvOption()
scene_option.flags[enums.mjtVisFlag.mjVIS_JOINT] = True
pixels = physics.render(scene_option=scene_option)
PIL.Image.fromarray(pixels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 physics = mujoco.Physics.from_xml_string(contents)
#       2 # Visualize the joint axis.
#       3 scene_option = mujoco.wrapper.core.MjvOption()
#
# File ~/anaconda3/envs/metaGarage/lib/python3.9/site-packages/dm_control/mujoco/engine.py:423, in Physics.from_xml_string(cls, xml_string, assets)
#     409 @classmethod
#     410 def from_xml_string(cls, xml_string, assets=None):
#     411   """A named constructor from a string containing an MJCF XML file.
#     412
#     413   Args:
#    (...)
#     421     A new `Physics` instance.
#     422   """
# --> 423   model = wrapper.MjModel.from_xml_string(xml_string, assets=assets)
#     424   return cls.from_model(model)
#
# File ~/anaconda3/envs/metaGarage/lib/python3.9/site-packages/dm_control/mujoco/wrapper/core.py:302, in MjModel.from_xml_string(cls, xml_string, assets)
#     288 @classmethod
#     289 def from_xml_string(cls, xml_string, assets=None):
#     290   """Creates an `MjModel` instance from a model description XML string.
#     291
#     292   Args:
#    (...)
#     300     An `MjModel` instance.
#     301   """
# --> 302   model_ptr = _get_model_ptr_from_xml(xml_string=xml_string, assets=assets)
#     303   return cls(model_ptr)
#
# File ~/anaconda3/envs/metaGarage/lib/python3.9/site-packages/dm_control/mujoco/wrapper/core.py:187, in _get_model_ptr_from_xml(xml_path, xml_string, assets)
#     183   raise TypeError(
#     184       "Only one of `xml_path` or `xml_string` may be specified.")
#     186 if xml_string is not None:
# --> 187   ptr = mujoco.MjModel.from_xml_string(xml_string, assets or {})
#     188 else:
#     189   ptr = mujoco.MjModel.from_xml_path(xml_path, assets or {})
#
# ValueError: XML Error: Include error: 'XML parse error 3:
# Error=XML_ERROR_FILE_NOT_FOUND ErrorID=3 (0x3) Line number=0: filename=shared_config.xml
# '
# Element 'include', line 3

# %%
duration = 20   # (seconds)
framerate = 30  # (Hz)

# Visualize the joint axis
scene_option = mujoco.wrapper.core.MjvOption()
scene_option.flags[enums.mjtVisFlag.mjVIS_JOINT] = True

# Simulate and display video.
frames = []
physics.reset()  # Reset state and time
while physics.data.time < duration:
  physics.step()
  if len(frames) < physics.data.time * framerate:
    pixels = physics.render(scene_option=scene_option)
    frames.append(pixels)
display_video(frames, framerate)
# Out:
# <video width="320" height="240" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
